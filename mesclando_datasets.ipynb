# %% [markdown]
# ### Importando as Bibliotecas

# %%
import pandas as pd

# %% [markdown]
# ### 1. População mundial em 2021
# https://www.kaggle.com/datasets/rsrishav/world-population

# %%
df1 = pd.read_csv('datasets/2022_population.csv')

# %%
#para ver todas as colunas do df
pd.set_option('display.max_rows', None)

# %%
df1.head()
# Out:
#   iso_code        country 2022_last_updated 2020_population             area  \
# 0      CHN          China     1,425,873,641   1,424,929,781  9,706,961 sq_km
# 1      IND          India     1,418,914,739   1,396,387,127  3,287,590 sq_km
# 2      USA  United States       338,573,477     335,942,003  9,372,610 sq_km
# 3      IDN      Indonesia       275,818,905     271,857,970  1,904,569 sq_km
# 4      PAK       Pakistan       236,650,690     227,196,741    881,912 sq_km
#
#   density_sq_km growth_rate world_%  rank
# 0     147/sq_km      -0.00%  17.88%     1
# 1     431/sq_km       0.68%  17.77%     2
# 2      36/sq_km       0.38%   4.24%     3
# 3     145/sq_km       0.64%   3.45%     4
# 4     267/sq_km       1.91%   2.96%     5

# %%
df1.loc[df1.iso_code == 'BRA']
# Out:
#   iso_code country 2022_last_updated 2020_population             area  \
# 6      BRA  Brazil       215,488,926     213,196,304  8,515,767 sq_km
#
#   density_sq_km growth_rate world_%  rank
# 6      25/sq_km       0.46%   2.70%     7

# %%
#selecionando as colunas que interessam
df2 = df1[['iso_code', 'country', '2022_last_updated', 'rank']]

# %%
df2.head()
# Out:
#   iso_code        country 2022_last_updated  rank
# 0      CHN          China     1,425,873,641     1
# 1      IND          India     1,418,914,739     2
# 2      USA  United States       338,573,477     3
# 3      IDN      Indonesia       275,818,905     4
# 4      PAK       Pakistan       236,650,690     5

# %%
#visualizando o tamanho do df
df2.shape
# Out:
# (216, 4)

# %% [markdown]
# ### 2. Preços da Internet
# https://www.kaggle.com/datasets/ramjasmaurya/1-gb-internet-price

# %%
df3 = pd.read_csv('datasets/all_csv sorted.csv')

# %%
df3.head()
# Out:
#    S.NO Country code     Country  Continental region  NO. OF Internet Plans  \
# 0     0           IL      Israel           NEAR EAST                   27.0
# 1     1           KG  Kyrgyzstan   CIS (FORMER USSR)                   20.0
# 2     2           FJ        Fiji             OCEANIA                   18.0
# 3     3           IT       Italy      WESTERN EUROPE                   29.0
# 4     4           SD       Sudan  SUB-SAHARAN AFRICA                   33.0
#
#   Average price of 1GB (USD)  Cheapest 1GB for 30 days (USD)  \
# 0                       0.05                            0.02
# 1                       0.15                            0.10
# 2                       0.19                            0.05
# 3                       0.27                            0.09
# 4                       0.27                            0.03
#
#    Most expensive 1GB (USD) Average price of 1GB (USD  at the start of 2021)  \
# 0                     20.95                                             0.11
# 1                      7.08                                             0.21
# 2                      0.85                                             0.59
# 3                      3.54                                             0.43
# 4                      0.92                                             0.63
#
#   Average price of 1GB (USD – at start of 2020) Internet users  Population  \
# 0                                           0.9      6,788,737   8,381,516
# 1                                          0.27      2,309,235   6,304,030
# 2                                          3.57        452,479     883,483
# 3                                          1.73     50,540,000  60,627,291
# 4                                          0.68     12,512,639  41,801,533
#
#    Avg \n(Mbit/s)Ookla
# 0                28.01
# 1                16.30
# 2                25.99
# 3                37.15
# 4                 9.50

# %%
#renomeando a coluna para mesclar
df3.rename(columns={'Country': 'country'}, inplace = True)

# %%
#selecionando as colunas que interessam
df4 = df3[['country', 'NO. OF Internet Plans', 'Average price of 1GB (USD)', 'Cheapest 1GB for 30 days (USD)', 'Most expensive 1GB (USD)', 'Internet users']]

# %%
df4.head()
# Out:
#       country  NO. OF Internet Plans Average price of 1GB (USD)  \
# 0      Israel                   27.0                       0.05
# 1  Kyrgyzstan                   20.0                       0.15
# 2        Fiji                   18.0                       0.19
# 3       Italy                   29.0                       0.27
# 4       Sudan                   33.0                       0.27
#
#    Cheapest 1GB for 30 days (USD)  Most expensive 1GB (USD) Internet users
# 0                            0.02                     20.95      6,788,737
# 1                            0.10                      7.08      2,309,235
# 2                            0.05                      0.85        452,479
# 3                            0.09                      3.54     50,540,000
# 4                            0.03                      0.92     12,512,639

# %%
#mesclando os dataframes
data = pd.merge(df2, df4, how = 'inner', on = 'country')
data.head()
# Out:
#   iso_code        country 2022_last_updated  rank  NO. OF Internet Plans  \
# 0      CHN          China     1,425,873,641     1                   36.0
# 1      IND          India     1,418,914,739     2                   58.0
# 2      USA  United States       338,573,477     3                   45.0
# 3      IDN      Indonesia       275,818,905     4                   53.0
# 4      PAK       Pakistan       236,650,690     5                   60.0
#
#   Average price of 1GB (USD)  Cheapest 1GB for 30 days (USD)  \
# 0                       0.52                            0.30
# 1                       0.68                            0.05
# 2                       3.33                            1.00
# 3                       0.42                            0.17
# 4                       0.59                            0.06
#
#    Most expensive 1GB (USD) Internet users
# 0                      1.21  1,010,740,000
# 1                      2.73    833,710,000
# 2                     30.00    312,320,000
# 3                      2.94    196,000,000
# 4                      8.59    118,800,000

# %%
#visualizando o tamanho do df
data.shape
# Out:
# (202, 9)

# %% [markdown]
# ### 3. Uso Global da Internet
# https://www.kaggle.com/datasets/sansuthi/gapminder-internet

# %%
df5 = pd.read_csv('datasets/gapminder_internet.csv')
df5.head()
# Out:
#        country  incomeperperson  internetuserate  urbanrate
# 0  Afghanistan              NaN         3.654122      24.04
# 1      Albania      1914.996551        44.989947      46.72
# 2      Algeria      2231.993335        12.500073      65.22
# 3      Andorra     21943.339900        81.000000      88.92
# 4       Angola      1381.004268         9.999954      56.70

# %%
#selecionando as colunas que interessam
df6 = df5[['country', 'incomeperperson', 'urbanrate']]

# %%
#mesclando os dataframes
data = pd.merge(data, df6, how = 'inner', on = 'country')
data.head()
# Out:
#   iso_code        country 2022_last_updated  rank  NO. OF Internet Plans  \
# 0      CHN          China     1,425,873,641     1                   36.0
# 1      IND          India     1,418,914,739     2                   58.0
# 2      USA  United States       338,573,477     3                   45.0
# 3      IDN      Indonesia       275,818,905     4                   53.0
# 4      PAK       Pakistan       236,650,690     5                   60.0
#
#   Average price of 1GB (USD)  Cheapest 1GB for 30 days (USD)  \
# 0                       0.52                            0.30
# 1                       0.68                            0.05
# 2                       3.33                            1.00
# 3                       0.42                            0.17
# 4                       0.59                            0.06
#
#    Most expensive 1GB (USD) Internet users  incomeperperson  urbanrate
# 0                      1.21  1,010,740,000      2425.471293      43.10
# 1                      2.73    833,710,000       786.700098      29.54
# 2                     30.00    312,320,000     37491.179520      81.70
# 3                      2.94    196,000,000      1143.831514      51.46
# 4                      8.59    118,800,000       668.547943      36.16

# %%
#visualizando o tamanho do df
data.shape
# Out:
# (180, 11)

# %% [markdown]
# ### 4. Países por número de usuários da Internet
# https://www.kaggle.com/datasets/tanuprabhu/list-of-countries-by-number-of-internet-users

# %%
df7 = pd.read_csv('datasets/List of Countries by number of Internet Users - Sheet1.csv')

# %%
df7.head()
# Out:
#   Country or Area Internet Users     Population  Rank Percentage Rank.1
# 0           China    765,367,947  1,409,517,397     1     54.30%    116
# 1           India    461,347,554  1,339,180,127     2     34.45%    145
# 2   United States    244,090,854    324,459,463     3     75.23%     68
# 3          Brazil    141,206,801    209,288,278     4     67.47%     83
# 4           Japan    115,845,120    127,484,450     5     90.87%     23

# %%
#renomeando a coluna para mesclar
df7.rename(columns={'Country or Area': 'country'}, inplace = True)

# %%
#selecionando as colunas que interessam
df8 = df7[['country', 'Percentage', 'Rank.1']]

# %%
#mesclando os df
data = pd.merge(data, df8, how = 'inner', on = 'country')
data.head()
# Out:
#   iso_code        country 2022_last_updated  rank  NO. OF Internet Plans  \
# 0      CHN          China     1,425,873,641     1                   36.0
# 1      IND          India     1,418,914,739     2                   58.0
# 2      USA  United States       338,573,477     3                   45.0
# 3      IDN      Indonesia       275,818,905     4                   53.0
# 4      PAK       Pakistan       236,650,690     5                   60.0
#
#   Average price of 1GB (USD)  Cheapest 1GB for 30 days (USD)  \
# 0                       0.52                            0.30
# 1                       0.68                            0.05
# 2                       3.33                            1.00
# 3                       0.42                            0.17
# 4                       0.59                            0.06
#
#    Most expensive 1GB (USD) Internet users  incomeperperson  urbanrate  \
# 0                      1.21  1,010,740,000      2425.471293      43.10
# 1                      2.73    833,710,000       786.700098      29.54
# 2                     30.00    312,320,000     37491.179520      81.70
# 3                      2.94    196,000,000      1143.831514      51.46
# 4                      8.59    118,800,000       668.547943      36.16
#
#   Percentage Rank.1
# 0     54.30%    116
# 1     34.45%    145
# 2     75.23%     68
# 3     32.29%    150
# 4     30.68%    184

# %%
#visualizando o tamanho do df
data.shape
# Out:
# (175, 13)

# %% [markdown]
# ### 5. Indicadores de desenvolvimento
# https://databank.worldbank.org/reports.aspx?source=2&country=BRA

# %%
df9 = pd.read_csv('datasets/WDICountry.csv')

# %%
df9.head()
# Out:
#   Country Code                   Short Name                   Table Name  \
# 0          ABW                        Aruba                        Aruba
# 1          AFE  Africa Eastern and Southern  Africa Eastern and Southern
# 2          AFG                  Afghanistan                  Afghanistan
# 3          AFW   Africa Western and Central   Africa Western and Central
# 4          AGO                       Angola                       Angola
#
#                       Long Name 2-alpha code   Currency Unit  \
# 0                         Aruba           AW   Aruban florin
# 1   Africa Eastern and Southern           ZH             NaN
# 2  Islamic State of Afghanistan           AF  Afghan afghani
# 3    Africa Western and Central           ZI             NaN
# 4   People's Republic of Angola           AO  Angolan kwanza
#
#                                        Special Notes  \
# 0                                                NaN
# 1  26 countries, stretching from the Red Sea in t...
# 2  The reporting period for national accounts dat...
# 3  22 countries, stretching from the westernmost ...
# 4  The World Bank systematically assesses the app...
#
#                       Region         Income Group WB-2 code  ...  \
# 0  Latin America & Caribbean          High income        AW  ...
# 1                        NaN                  NaN        ZH  ...
# 2                 South Asia           Low income        AF  ...
# 3                        NaN                  NaN        ZI  ...
# 4         Sub-Saharan Africa  Lower middle income        AO  ...
#
#      Government Accounting concept  \
# 0                              NaN
# 1                              NaN
# 2  Consolidated central government
# 3                              NaN
# 4     Budgetary central government
#
#                      IMF data dissemination standard Latest population census  \
# 0  Enhanced General Data Dissemination System (e-...          2020 (expected)
# 1                                                NaN                      NaN
# 2  Enhanced General Data Dissemination System (e-...                     1979
# 3                                                NaN                      NaN
# 4  Enhanced General Data Dissemination System (e-...                     2014
#
#                   Latest household survey  \
# 0                                     NaN
# 1                                     NaN
# 2     Demographic and Health Survey, 2015
# 3                                     NaN
# 4  Demographic and Health Survey, 2015/16
#
#   Source of most recent Income and expenditure data  \
# 0                                               NaN
# 1                                               NaN
# 2        Integrated household survey (IHS), 2016/17
# 3                                               NaN
# 4        Integrated household survey (IHS), 2008/09
#
#   Vital registration complete  Latest agricultural census  \
# 0                         Yes                         NaN
# 1                         NaN                         NaN
# 2                         NaN                         NaN
# 3                         NaN                         NaN
# 4                         NaN                         NaN
#
#    Latest industrial data Latest trade data Unnamed: 30
# 0                     NaN            2018.0         NaN
# 1                     NaN               NaN         NaN
# 2                     NaN            2018.0         NaN
# 3                     NaN               NaN         NaN
# 4                     NaN            2018.0         NaN
#
# [5 rows x 31 columns]

# %%
#renomeando a coluna para mesclar
df9.rename(columns={'Table Name': 'country'}, inplace = True)

# %%
#selecionando as colunas que interessam
df10 = df9[['country', 'Region', 'Income Group']]
df10.head()
# Out:
#                        country                     Region         Income Group
# 0                        Aruba  Latin America & Caribbean          High income
# 1  Africa Eastern and Southern                        NaN                  NaN
# 2                  Afghanistan                 South Asia           Low income
# 3   Africa Western and Central                        NaN                  NaN
# 4                       Angola         Sub-Saharan Africa  Lower middle income

# %%
#mesclando os df
data = pd.merge(data, df10, how = 'inner', on = 'country')
data.head()
# Out:
#   iso_code        country 2022_last_updated  rank  NO. OF Internet Plans  \
# 0      CHN          China     1,425,873,641     1                   36.0
# 1      IND          India     1,418,914,739     2                   58.0
# 2      USA  United States       338,573,477     3                   45.0
# 3      IDN      Indonesia       275,818,905     4                   53.0
# 4      PAK       Pakistan       236,650,690     5                   60.0
#
#   Average price of 1GB (USD)  Cheapest 1GB for 30 days (USD)  \
# 0                       0.52                            0.30
# 1                       0.68                            0.05
# 2                       3.33                            1.00
# 3                       0.42                            0.17
# 4                       0.59                            0.06
#
#    Most expensive 1GB (USD) Internet users  incomeperperson  urbanrate  \
# 0                      1.21  1,010,740,000      2425.471293      43.10
# 1                      2.73    833,710,000       786.700098      29.54
# 2                     30.00    312,320,000     37491.179520      81.70
# 3                      2.94    196,000,000      1143.831514      51.46
# 4                      8.59    118,800,000       668.547943      36.16
#
#   Percentage Rank.1               Region         Income Group
# 0     54.30%    116  East Asia & Pacific  Upper middle income
# 1     34.45%    145           South Asia  Lower middle income
# 2     75.23%     68        North America          High income
# 3     32.29%    150  East Asia & Pacific  Lower middle income
# 4     30.68%    184           South Asia  Lower middle income

# %%
#renomeando as colunas 
data.rename(columns={'iso_code': 'abreviacao', 'country': 'pais', '2022_last_updated': 'populacao', 'rank': 'rank_populacao', 'NO. OF Internet Plans': 'qtd_planos_internet', 'Average price of 1GB (USD)': '1GB_preco_medio', 'Cheapest 1GB for 30 days (USD)': '1GB_mais_barato', 'Most expensive 1GB (USD)': '1GB_mais_caro', 'Internet users': 'usuarios_internet', 'incomeperperson': 'PIB_per_capita', 'urbanrate': 'populacao_urbana_%', 'Percentage': 'usuarios_internet_%', 'Rank.1': 'rank_usuarios', 'Region': 'regiao', 'Income Group': 'grupo_renda'}, inplace = True)

# %%
data.head()
# Out:
#   abreviacao           pais      populacao  rank_populacao  \
# 0        CHN          China  1,425,873,641               1
# 1        IND          India  1,418,914,739               2
# 2        USA  United States    338,573,477               3
# 3        IDN      Indonesia    275,818,905               4
# 4        PAK       Pakistan    236,650,690               5
#
#    qtd_planos_internet 1GB_preco_medio  1GB_mais_barato  1GB_mais_caro  \
# 0                 36.0            0.52             0.30           1.21
# 1                 58.0            0.68             0.05           2.73
# 2                 45.0            3.33             1.00          30.00
# 3                 53.0            0.42             0.17           2.94
# 4                 60.0            0.59             0.06           8.59
#
#   usuarios_internet  PIB_per_capita  populacao_urbana_% usuarios_internet_%  \
# 0     1,010,740,000     2425.471293               43.10              54.30%
# 1       833,710,000      786.700098               29.54              34.45%
# 2       312,320,000    37491.179520               81.70              75.23%
# 3       196,000,000     1143.831514               51.46              32.29%
# 4       118,800,000      668.547943               36.16              30.68%
#
#   rank_usuarios               regiao          grupo_renda
# 0           116  East Asia & Pacific  Upper middle income
# 1           145           South Asia  Lower middle income
# 2            68        North America          High income
# 3           150  East Asia & Pacific  Lower middle income
# 4           184           South Asia  Lower middle income

# %%
#visualizando o tamanho do df
data.shape
# Out:
# (163, 15)

# %%
#criando arquivo em csv do novo dataset
data.to_csv('dataset.csv', index = False)
